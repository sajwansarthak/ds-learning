# %%
import numpy as np

# %%
arr = np.array([1,2,3])

# %%
arr
# Out:
# array([1, 2, 3])

# %%
rev_q1 = np.array([10,12,9])
rev_q1
# Out:
# array([10, 12,  9])

# %%
rev_q1.ndim
# Out:
# 1

# %%
rev = np.array([[10,12,9],[15,11,13]])
rev
# Out:
# array([[10, 12,  9],
#        [15, 11, 13]])

# %%
rev.ndim
# Out:
# 2

# %%
rev[1,0]
# Out:
# 15

# %%
rev[1,0] = 14

# %%
rev
# Out:
# array([[10, 12,  9],
#        [14, 11, 13]])

# %%
rev.nbytes  #number of bytes occupied by the array
# Out:
# 48

# %%
rev.itemsize
# Out:
# 8

# %%
rev.size
# Out:
# 6

# %%
rev.shape #gives the number of rows and columns
# Out:
# (2, 3)

# %%
np.sort(rev)
# Out:
# array([[ 9, 10, 12],
#        [11, 13, 14]])

# %%
 np.sort(rev,axis = None)
# Out:
# array([ 9, 10, 11, 12, 13, 14])

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.arange(20,30,2)
# Out:
# array([20, 22, 24, 26, 28])

# %%
np.linspace(10,20,5)
# Out:
# array([10. , 12.5, 15. , 17.5, 20. ])

# %%
rev.min()
# Out:
# 9

# %%
rev.max()
# Out:
# 14

# %%
rev.sum(axis = 1)
# Out:
# array([31, 38])

# %%
for row in rev:
    print("row ->", row)
# Out:
# row -> [10 12  9]
# row -> [14 11 13]

# %%
b = np.array([1,4,16])

# %%
np.sqrt(b)
# Out:
# array([1., 2., 4.])

# %%
np.square(b)
# Out:
# array([  1,  16, 256])

# %%
np.std(b)
# Out:
# 6.48074069840786
