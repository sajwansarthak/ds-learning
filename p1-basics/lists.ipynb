# %% [markdown]
# ## Lists

# %%
iteam1 = "bread"
iteam2 = "pasta"
iteam3 = "cheese"
iteam4 = "vegies"

# %%
#We use list so that we can store multiple items easily
items = ["bread","pasta","cheese","vegies"]
items
# Out:
# ['bread', 'pasta', 'cheese', 'vegies']

# %%
items[-1]
# Out:
# 'vegies'

# %%
items[0:2]
# Out:
# ['bread', 'pasta']

# %%
items.append("butter")
items
# Out:
# ['bread', 'pasta', 'cheese', 'vegies', 'butter', 'butter']

# %%
items.remove("butter")
items
# Out:
# ['bread', 'pasta', 'cheese', 'vegies']

# %%
items.insert(1,"butter")
items
# Out:
# ['bread', 'butter', 'pasta', 'cheese', 'vegies']

# %%
#lists are muteable
items[1] = "cheese"
items
# Out:
# ['bread', 'cheese', 'pasta', 'cheese', 'vegies']

# %%
items[3:] = ["almonds"]
items
# Out:
# ['bread', 'cheese', 'pasta', 'almonds']

# %%
'rice' in items
# Out:
# False

# %%
expences = [30,1200,34,22]
expences.sort()
expences
# Out:
# [22, 30, 34, 1200]

# %%
#lists in python can have random values 
random = ["car",20,True]
