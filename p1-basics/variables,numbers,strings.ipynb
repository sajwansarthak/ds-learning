# %%
can = "soda"
can
# Out:
# 'soda'

# %%
can = "bean"
can
# Out:
# 'bean'

# %%
type(can)
# Out:
# str

# %%
pizza = 100
noodles = 50
burger = 55.5

# %%
total = pizza + noodles + burger
total
# Out:
# 205.5

# %%
type(total)
# Out:
# float

# %% [markdown]
# above_threshold = total > 200
# above_threshold

# %%
type(above_threshold)
# Out:
# bool

# %%
foo = "jalebi"

# %%
bar = foo
bar
# Out:
# 'jalebi'

# %%
id(foo)
# Out:
# 5070811856

# %%
id(bar)
# Out:
# 5070811856

# %%
name_person = "sarthak"

# %%
name_person
# Out:
# 'sarthak'

# %% [markdown]
# #### Numbers

# %%
height = 7
base = 10

area = (base * height)/2
area
# Out:
# 35.0

# %%
type(area)
# Out:
# float

# %%
x = 3
y = 10

# %%
y//x
# Out:
# 3

# %%
x%y
# Out:
# 3

# %%
foo = 2.3e4
foo
# Out:
# 23000.0

# %%
#using math function
import math

x = 16
x = math.sqrt(x)
x
# Out:
# 4.0

# %%
math.floor(3.7)
# Out:
# 3

# %%
math.ceil(3.7)
# Out:
# 4

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
#binary representation

format(5, 'b')
# Out:
# '101'

# %% [markdown]
# ## Strings

# %%
first = 'sarthak'
last = "sajwan"

# %%
name = first +" "+ last
name
# Out:
# 'sarthak sajwan'

# %%
#using pyhton format string
name = f"{first} {last}"
name
# Out:
# 'sarthak sajwan'

# %%
age = 20

info = f"{first} {last} is {age} years old"
info
# Out:
# 'sarthak sajwan is 20 years old'

# %%
name[7:]
# Out:
# ' sajwan'

# %%
name[-1]
# Out:
# 'n'

# %%
 #strings are immutable in python

# %%
tickers = "AAPL|NVDA|GOGL"
tickers.split("|")
# Out:
# ['AAPL', 'NVDA', 'GOGL']

# %%
#to remove the white spaces from the data we can use data.strip()
